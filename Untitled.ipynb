# %% [markdown]
# # CSC ASSIGNMENT
# ## BY: CSC/19d/
# _______________
#
# ### COURSE WORK:
#
# - Using these AI chat tools namely ChatGPT, Perplexity AI and BlackBox AI demonstrate how prompts can be used to design, develop and -deploy a multimedia app on a server.
#
# ###### Submit both the prompts and the results in chronological order.

# %% [markdown]
# # promt 1
# i want to build a multimedia application. List out some use cases of multimedia applications.

# %% [markdown]
# #response
#
#
# * Multimedia applications have diverse use cases across various fields. In education, they enhance learning with interactive modules and virtual classrooms. Entertainment benefits from streaming services, multimedia-rich games, and VR experiences. Businesses use multimedia for video conferencing and corporate training. Healthcare applications include telemedicine and medical training simulations. Social media platforms thrive on photo, video sharing, and virtual communities. Creative arts leverage photo/video editing and digital animation tools. In travel, multimedia offers virtual tours and interactive guides. E-commerce utilizes product demos and AR try-ons. News platforms feature interactive stories and multimedia podcasts. Lastly, cultural preservation uses digital archives and storytelling platforms to share cultural heritage.

# %% [markdown]
# # promt 2
# I am familiar with tkinter and I need you to list out the steps to build this application.

# %% [markdown]
# # Response
#
# Building a multimedia application using Tkinter involves several steps, from planning and design to coding and testing. Below are the steps to guide you through the process:
#
# Define Requirements:
#
# Identify the core functionalities you need (e.g., video playback, audio streaming, image display).
# Determine the specific features based on your use case (e.g., education, entertainment, etc.).
# Design the User Interface:
#
# Sketch the layout of your application, including buttons, menus, and multimedia display areas.
# Plan the user interactions and navigation flow.
# Set Up the Development Environment:
#
# Install Python and Tkinter if not already installed.
# Install additional libraries for multimedia handling (e.g., Pillow for images, pygame for audio, tkVideoPlayer for video).
# Create the Main Application Structure:
#
# Initialize the Tkinter application.
# Set up the main window and configure its properties (size, title, etc.).
# Define the main frames and layout using Frame, Grid, or Pack

# %% [markdown]
# # observations
#  the AI tool is very powerful but it still require human skill to build the application

# %% [markdown]
# # promt 3
# write tkinter with a nice interface that convert my PDF into AUDIO format and every convertion should be save in a file as the database that allowed me to use the audio file any time

# %% [markdown]
# # Response
# Creating a Tkinter application that converts PDF files into audio format involves several steps. This application will use PyPDF2 to extract text from PDFs and gTTS (Google Text-to-Speech) to convert text to audio. It will also save conversion details to a CSV file to serve as a simple database.
#
# First, install the necessary libraries if you haven't already:

# %%
pip install PyPDF2 gtts tkinter pandas
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement tkinter (from versions: none)
# ERROR: No matching distribution found for tkinter
# Note: you may need to restart the kernel to use updated packages.

# %%
import tkinter as tk
from tkinter import filedialog, messagebox
from PyPDF2 import PdfFileReader
from gtts import gTTS
import os
import pandas as pd
import time
from playsound import playsound
import threading
import fitz  # PyMuPDF
from PIL import Image, ImageTk

# Function to read PDF file and extract text
def extract_text_from_pdf(file_path):
    with open(file_path, "rb") as pdf_file:
        reader = PdfFileReader(pdf_file)
        text = ""
        for page_num in range(reader.numPages):
            page = reader.getPage(page_num)
            text += page.extract_text()
    return text

# Function to convert text to audio
def convert_text_to_audio(text, audio_file_path):
    tts = gTTS(text)
    tts.save(audio_file_path)

# Function to save conversion details to CSV database
def save_to_database(pdf_file, audio_file):
    database_file = "conversions.csv"
    timestamp = time.strftime("%Y-%m-%d %H:%M:%S")
    
    if os.path.exists(database_file):
        df = pd.read_csv(database_file)
    else:
        df = pd.DataFrame(columns=["Timestamp", "PDF File", "Audio File"])
    
    df = df.append({"Timestamp": timestamp, "PDF File": pdf_file, "Audio File": audio_file}, ignore_index=True)
    df.to_csv(database_file, index=False)

# Function to handle file opening and conversion process
def open_pdf():
    file_path = filedialog.askopenfilename(filetypes=[("PDF files", "*.pdf")])
    if file_path:
        try:
            # Extract text from PDF
            global text
            text = extract_text_from_pdf(file_path)
            if not text.strip():
                messagebox.showerror("Error", "No text found in PDF.")
                return
            
            # Display PDF
            display_pdf(file_path)

            # Enable play button
            play_button.config(state="normal")
        except Exception as e:
            messagebox.showerror("Error", str(e))

# Function to display PDF
def display_pdf(file_path):
    pdf_document = fitz.open(file_path)
    page = pdf_document.load_page(0)  # Load first page
    pix = page.get_pixmap()
    image = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
    image.thumbnail((400, 400), Image.ANTIALIAS)
    pdf_image = ImageTk.PhotoImage(image)

    pdf_label.config(image=pdf_image)
    pdf_label.image = pdf_image

# Function to play audio file
def play_audio():
    audio_file = "temp_audio.mp3"
    convert_text_to_audio(text, audio_file)
    threading.Thread(target=playsound, args=(audio_file,), daemon=True).start()

# Function to view conversion history
def view_history():
    database_file = "conversions.csv"
    if os.path.exists(database_file):
        df = pd.read_csv(database_file)
        history_window = tk.Toplevel(root)
        history_window.title("Conversion History")
        
        text_widget = tk.Text(history_window)
        text_widget.pack(expand=True, fill="both")
        
        for index, row in df.iterrows():
            text_widget.insert(tk.END, f"Timestamp: {row['Timestamp']}\nPDF File: {row['PDF File']}\nAudio File: {row['Audio File']}\n\n")
    else:
        messagebox.showinfo("Info", "No conversion history found.")

# Initialize Tkinter window
root = tk.Tk()
root.title("PDF to Audio Converter")
root.geometry("600x600")
root.configure(bg="#f0f0f0")

# Create and place widgets
tk.Button(root, text="Open PDF", command=open_pdf, bg="#4CAF50", fg="white").pack(pady=20)
tk.Button(root, text="View Conversion History", command=view_history, bg="#2196F3", fg="white").pack(pady=20)
play_button = tk.Button(root, text="Play Audio", command=play_audio, state="disabled", bg="#FF9800", fg="white")
play_button.pack(pady=20)

# PDF display label
pdf_label = tk.Label(root, bg="#f0f0f0")
pdf_label.pack(pady=20)

root.mainloop()
# Out:
# playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/x00whitejsx/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 715, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/home/x00whitejsx/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 467, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/home/x00whitejsx/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 462, in _make_request
#     httplib_response = conn.getresponse()
#                        ^^^^^^^^^^^^^^^^^^
#   File "/home/x00whitejsx/anaconda3/lib/python3.11/http/client.py", line 1386, in getresponse
# ...

# %% [markdown]
# - Explanation:
# Libraries and Functions:
#
# * PyPDF2: To extract text from PDF files.
# gTTS: To convert text to speech.
# Pandas: To handle CSV file operations for the conversion history.
# Tkinter: To create the graphical user interface.
# Main Functions:
#
# * open_pdf(): Opens a file dialog to select a PDF file.
# convert_to_audio(file_path): Extracts text from the PDF and converts it to an audio file.
# save_to_database(pdf_file, audio_file): Saves the conversion details to a CSV file.
# view_history(): Displays the conversion history in a new window.
# User Interface:
#
# The main window contains buttons to open a PDF file and view the conversion history.

# %% [markdown]
# # promt 4
# write the unittest for the generated code

# %% [markdown]
# # response
#
# To write unittests for the provided Tkinter application, we will use the unittest module. Testing Tkinter applications can be challenging due to their graphical nature, but we can test the core functionalities such as PDF to text extraction, text to audio conversion, and database updates.
#
# Here is how you can create unittests for the core functions:
#
# - Test the PDF to text extraction function.
# - Test the text to audio conversion function.
# - Test the database update function.
# * First, install unittest if you haven't already (though it should be included with Python by default).

# %%
pip install unittest

# %%
import unittest
from unittest.mock import patch, mock_open, MagicMock
from my_app import extract_text_from_pdf, convert_text_to_audio, save_to_database
import os
import pandas as pd

class TestPDFToAudioConverter(unittest.TestCase):
    
    @patch("builtins.open", new_callable=mock_open, read_data="PDF content")
    @patch("PyPDF2.PdfFileReader")
    def test_extract_text_from_pdf(self, mock_pdf_reader, mock_open_file):
        # Mock PDF reader behavior
        mock_pdf = MagicMock()
        mock_pdf.numPages = 1
        mock_pdf.getPage().extract_text.return_value = "Sample text"
        mock_pdf_reader.return_value = mock_pdf
        
        # Test the function
        text = extract_text_from_pdf("dummy.pdf")
        self.assertEqual(text, "Sample text")
        
    @patch("gtts.gTTS.save")
    def test_convert_text_to_audio(self, mock_save):
        # Test the function
        convert_text_to_audio("Sample text", "output.mp3")
        mock_save.assert_called_once()
        
    @patch("pandas.DataFrame.to_csv")
    def test_save_to_database(self, mock_to_csv):
        # Remove existing database file if exists
        if os.path.exists("conversions.csv"):
            os.remove("conversions.csv")
        
        # Test the function
        save_to_database("input.pdf", "output.mp3")
        
        # Verify that the CSV file was written
        mock_to_csv.assert_called_once()

if __name__ == '__main__':
    unittest.main()

# %% [markdown]
# Explanation:
# Test extract_text_from_pdf:
#
# Mocks the open function and PdfFileReader to simulate reading a PDF and extracting text.
# Test convert_text_to_audio:
#
# Mocks the save method of gTTS to verify the text-to-audio conversion without actually creating an audio file.
# Test save_to_database:
#
# Mocks the to_csv method of Pandas DataFrame to check if the database update is performed correctly.
# Running the Tests
# Run the tests using the command:

# %%
python -m unittest test_app.py

# %% [markdown]
# # promt 5
# how do in convert it to run one windows, and linux operation system

# %% [markdown]
# # Response
#
# To ensure your Tkinter application runs on both Windows and Linux operating systems, you need to make sure your code is platform-independent and properly packaged. Below are the steps to achieve this:
#
# Make Code Platform-Independent:
#
# Ensure there are no OS-specific paths or commands in your code.
# Use libraries that are available on both Windows and Linux.
# Package the Application:
#
# Use PyInstaller to create executable files for Windows and Linux.
# Test the Application on Both Platforms:
#
# Verify the application works correctly on both Windows and Linux.
# Step-by-Step Guide
# 1. Platform-Independent Code
# The provided Tkinter application is already quite platform-independent. However, ensure all file paths are handled using os.path to ensure compatibility across different operating systems.
#
# 2. Packaging with PyInstaller
# Install PyInstaller:

# %%
pip install pyinstaller

# %% [markdown]
# Create Executable for Windows:
#
# - Open Command Prompt.
# Navigate to the directory containing your my_app.py (replace my_app.py with the actual filename).

# %%
pyinstaller --onefile --windowed app.py

# %% [markdown]
# --onefile: Creates a single executable file.
# --windowed: Hides the console window (useful for GUI applications).
# #### Create Executable for Linux:
#
# Open Terminal.
# Navigate to the directory containing your my_app.py.

# %%
pyinstaller --onefile --windowed my_app.py

# %% [markdown]
# - 3. Test the Application
# On Windows:
#
# Locate the generated executable file in the dist folder.
# Run the executable to test the application.
# On Linux:
#
# Locate the generated executable file in the dist folder.
# Ensure the file has execution permissions:

# %%
chmod +x my_app

# %% [markdown]
# # promt 6
# i want to host the application, write a simple HTML that allowed user to download the Application

# %% [markdown]
# # Response
#
#
# To host your application and provide users with a simple HTML page to download it, you'll need to:
#
# Create the HTML page with download links for the application executables.
# Ensure the executables are hosted on a server accessible via the web.
# Below is an example of a simple HTML page that allows users to download the application for Windows and Linux:
#
# * 1. HTML Page
# Create an HTML file, e.g., index.html

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PDF to Audio Converter Download</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            text-align: center;
            margin-top: 50px;
        }
        .download-button {
            display: inline-block;
            padding: 10px 20px;
            margin: 20px;
            font-size: 16px;
            color: white;
            background-color: #4CAF50;
            text-decoration: none;
            border-radius: 5px;
        }
        .download-button:hover {
            background-color: #45a049;
        }
    </style>
</head>
<body>
    <h1>Download PDF to Audio Converter</h1>
    <p>Select your operating system to download the application:</p>
    <a href="https://yourusername.github.io/my-app/my_app.exe" class="download-button">Download for Windows</a>
    <a href="https://yourusername.github.io/my-app/my_app" class="download-button">Download for Linux</a>
</body>
</html>

# %% [markdown]
# 2. Hosting the Executables
# Option 1: Using a Web Hosting Service
# Upload Files:
#
# Upload my_app.exe and my_app to your web hosting server.
# Ensure the files are in a publicly accessible directory.
# Adjust HTML Links:
#
# Update the href attributes in the HTML file with the correct paths to the executables on your server.
# Option 2: Using GitHub Pages (for small files)
# Create a GitHub Repository:
#
# Create a new repository on GitHub.
# Upload the executables and the HTML file to the repository.
# Enable GitHub Pages:
#
# Go to the repository settings.
# Scroll down to the "GitHub Pages" section.
# Select the main branch (or another branch if you prefer) as the source for GitHub Pages.
# Get the GitHub Pages URL:
#
# Once GitHub Pages is enabled, you'll get a Adjust HTML Links:
#
# Update the href attributes in the HTML file with the GitHub Pages URL pointing to the executables.

# %% [markdown]
# # Hosting and deployment
# list 3 free hosting site that can be use to host this application in summerised table

# %% [markdown]
# # Response
#
# | Hosting Service | Static Content | Custom Domain | SSL Support | Serverless Functions | Continuous Deployment | Bandwidth/Usage Limits |
# |-----------------|----------------|---------------|-------------|----------------------|-----------------------|------------------------|
# | GitHub Pages    | Yes            | Yes           | Yes         | No                   | Yes                   | Yes                    |
# | Netlify         | Yes            | Yes           | Yes         | Yes                  | Yes                   | Yes                    |
# | Vercel          | Yes            | Yes           | Yes         | Yes                  | Yes                   | Yes                    |
